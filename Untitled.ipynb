# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       5
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_csv("insurance_fraud_dataset_500k (1).csv")
df.head()
# Out:
#       claim_id policy_number  customer_id policy_state  policy_age_months  \
# 0  CLM-0000001   POL-0018493  CUST-226628           NC                 25
# 1  CLM-0000002   POL-0039940  CUST-262040           OH                 24
# 2  CLM-0000003   POL-0060815  CUST-836451           MI                195
# 3  CLM-0000004   POL-0014987  CUST-447699           IL                 43
# 4  CLM-0000005   POL-0010299  CUST-347953           WA                 57
#
#    policy_annual_premium  policy_deductible  umbrella_limit  \
# 0                2221.81               1000               0
# 1                1858.92               2000          500000
# 2                1276.74                500          100000
# 3                1507.47               1500         1000000
# 4                1408.21                500          100000
#
#   insured_education_level insured_occupation  ...  policy_changes_last_6m  \
# 0             High School              Sales  ...                       0
# ...

# %%
df.shape
# Out:
# (500000, 54)

# %%
df.describe()
# Out:
#        policy_age_months  policy_annual_premium  policy_deductible  \
# count      500000.000000          500000.000000      500000.000000
# mean           45.687380            1490.878071         813.256500
# std            46.181755             493.329162         439.475968
# min             1.000000             400.000000         250.000000
# 25%            12.000000            1150.400000         500.000000
# 50%            31.000000            1486.850000         750.000000
# 75%            64.000000            1824.750000        1000.000000
# max           240.000000            3670.300000        2000.000000
#
#        umbrella_limit            age  customer_tenure_months  capital_gains  \
# count   500000.000000  500000.000000           500000.000000  500000.000000
# mean    191979.200000      44.199682               24.384366   16437.210000
# std     241465.408243      12.766816               25.341391   24481.353641
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 54 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   claim_id                     500000 non-null  object
#  1   policy_number                500000 non-null  object
#  2   customer_id                  500000 non-null  object
#  3   policy_state                 500000 non-null  object
#  4   policy_age_months            500000 non-null  int64
#  5   policy_annual_premium        500000 non-null  float64
#  6   policy_deductible            500000 non-null  int64
#  7   umbrella_limit               500000 non-null  int64
#  8   insured_education_level      500000 non-null  object
#  9   insured_occupation           500000 non-null  object
#  10  age                          500000 non-null  int64
#  11  customer_tenure_months       500000 non-null  int64
# ...

# %%
df.fraud_reported.value_counts(normalize=True)
# Out:
# fraud_reported
# 0    0.962
# 1    0.038
# Name: proportion, dtype: float64
